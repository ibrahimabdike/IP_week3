# %% [markdown]
# <a href="https://colab.research.google.com/github/yahyalito/IP_week3/blob/master/Moringa_Data_Science_Prep_W3_Independent_Project_2019_07_Ibrahim_Yahya_DataReport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1_url = "http://bit.ly/TelecomDataset1"
df1 = pd.read_csv(df1_url)

# %%
df1.head(5)
# Out:
#   PRODUTC  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3   Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
#
# [5 rows x 10 columns]

# %%
df2_url = "http://bit.ly/TelecomDataset2"
df2 = pd.read_csv(df2_url)

# %%
df2.head(4)
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0     sms      0  2012-05-07 23:02:06.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 1   Voice      0  2012-05-07 23:03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 2     sms      0  2012-05-07 23:04:06.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 3   Voice     37  2012-05-07 23:04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
#
# [4 rows x 10 columns]

# %%
df3_url = "http://bit.ly/TelecomDataset3"
df3 = pd.read_csv(df3_url)
df3
# Out:
#          PRODUCT  VALUE  ...      CELLID     SIET_ID
# 0          Voice     61  ...  +38u2u/rfx  +38u2u/rfx
# 1            sms      0  ...  +Fs4mTvdKx  +Fs4mTvdKx
# 2          Voice     10  ...  +ZaaZozy/+  +ZaaZozy/+
# 3            sms      0  ...  +cNeJzsTp3  +cNeJzsTp3
# 4          Voice     22  ...  /eeMklgyJA  /eeMklgyJA
# 5          Voice     10  ...  +e+xcimwre  +e+xcimwre
# 6            sms      0  ...  +R5ccmtyJf  +R5ccmtyJf
# 7          Voice     10  ...  +ZaaZozy/+  +ZaaZozy/+
# 8            sms     25  ...  13O1+JEun3  13O1+JEun3
# 9            sms      0  ...  /eeMklgyJA  /eeMklgyJA
# 10           sms      0  ...  /eeMklgyJA  /eeMklgyJA
# 11           sms      0  ...  /NPTR0H+5I  /NPTR0H+5I
# 12           sms      0  ...  18MlD9e2CO  18MlD9e2CO
# 13           sms      0  ...  0K+IDi1yjl  0K+IDi1yjl
# 14           sms      0  ...  2GgIN622rt  2GgIN622rt
# 15           sms     50  ...  051KhYDCpv  051KhYDCpv
# 16         Voice     14  ...  2aXXOLyR5M  2aXXOLyR5M
# ...

# %%
df = pd.read_csv('cells_geo.csv', delimiter = ',')
df.head(5)
# Out:
#   ;VILLES;STATUS;LOCALISATION;DECOUPZONE;ZONENAME;LONGITUDE;LATITUDE;REGION;AREA;CELL_ID;SITE_CODE
# 0  0;ADJAME;In Service;ABIDJAN;"""Abidjan_EST";AG...
# 1  1;ADJAME;In Service;ABIDJAN;"""Abidjan_EST";AG...
# 2  2;ADJAME;In Service;ABIDJAN;"""Abidjan_EST";AG...
# 3  3;ASSINIE;In Service;INTERIEUR;Grand-EST;"ASSI...
# 4  4;ASSINIE;In Service;INTERIEUR;Grand-EST;"ASSI...

# %%
url1 = 'CDR_description.xlsx'
df4 = pd.read_excel(url1, sheet_name=0, header=1)
df4.head(5)
# Out:
#            PRODUCT                                       Voice or SMS   String
# 0            VALUE                                      Billing price  Integer
# 1        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 2     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 3  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 4  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String

# %%
url1 = 'cells_geo_description.xlsx'
df5 = pd.read_excel(url1, sheet_name=0, header=1)
df5.head(5)
# Out:
#          VILLES               City  String
# 0        STATUS  In Service or not  String
# 1  LOCALISATION  in ABIDJAN or not  String
# 2    DECOUPZONE  Geographical Zone  String
# 3      ZONENAME       Name of Zone  String
# 4     LONGITUDE          Longitude   Float

# %%
new_df1 =df1.rename(columns={'PRODUTC':'PRODUCT','DATETIME':'DATE_TIME'})

# %%
new_df1
# Out:
#          PRODUCT  VALUE  ...     CELL_ID     SITE_ID
# 0          Voice      0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1            sms      0  ...  /+cKZKIp41  /+cKZKIp41
# 2            sms     25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3          Voice     56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4          Voice     14  ...  051KhYDCpv  051KhYDCpv
# 5           data      0  ...  /lrUXVGVcN  /lrUXVGVcN
# 6          Voice      0  ...  +38u2u/rfx  +38u2u/rfx
# 7          Voice      0  ...  09UjmmY1Ds  09UjmmY1Ds
# 8          Voice      0  ...  0DeimCpZOc  0DeimCpZOc
# 9            sms      0  ...  01MDiY5F89  01MDiY5F89
# 10           sms      0  ...  0Fmr/IZtQ+  0Fmr/IZtQ+
# 11           sms      0  ...  0MZBLLzPYZ  0MZBLLzPYZ
# 12           sms      0  ...  0//cZOoEXj  0//cZOoEXj
# 13           sms     25  ...  2dmu2Iy1CX  2dmu2Iy1CX
# 14         Voice      0  ...  0Fmr/IZtQ+  0Fmr/IZtQ+
# 15         Voice      0  ...  176sGHv7Ym  176sGHv7Ym
# 16         Voice     44  ...  ++ctND+jGD  ++ctND+jGD
# ...

# %%
new_df1['PRODUCT'].head()
# Out:
# 0    Voice
# 1      sms
# 2      sms
# 3    Voice
# 4    Voice
# Name: PRODUCT, dtype: object

# %%
#maximum value 
new_df1['VALUE'].max()
# Out:
# 24960

# %%
#Checking for Unique
new_df1.PRODUCT.unique()
# Out:
# array(['Voice', 'sms', 'data'], dtype=object)

# %%
#MEAN OF products value
value = new_df1['VALUE'].groupby(new_df1['PRODUCT'])
value.mean()
# Out:
# PRODUCT
# Voice    63.131849
# data      5.138220
# sms       2.444787
# Name: VALUE, dtype: float64

# %%
value.cumsum()
# Out:
# 0                   0
# 1                   0
# 2                  25
# 3                  56
# 4                  70
# 5                   0
# 6                  70
# 7                  70
# 8                  70
# 9                  25
# 10                 25
# 11                 25
# 12                 25
# 13                 50
# 14                 70
# 15                 70
# 16                114
# 17                114
# 18                 50
# 19                128
# 20                  0
# 21                 50
# 22                100
# 23                  0
# 24                128
# 25                  0
# 26                128
# 27                147
# 28                125
# 29                125
#               ...
# 15011786     11219509
# 15011787    624894003
# 15011788     11219509
# 15011789    624894023
# 15011790     11219509
# 15011791     11219509
# 15011792    624894053
# 15011793     11219509
# 15011794    624894083
# 15011795     11219509
# ...

# %%
value.describe()
# Out:
#              count       mean         std  min   25%   50%   75%      max
# PRODUCT
# Voice    9898239.0  63.131849  102.767427  0.0  12.0  35.0  79.0  24960.0
# data      524411.0   5.138220  102.170704  0.0   0.0   0.0   0.0  21049.0
# sms      4589166.0   2.444787   10.926157  0.0   0.0   0.0   0.0    500.0

# %%
value.count()
# Out:
# PRODUCT
# Voice    9898239
# data      524411
# sms      4589166
# Name: VALUE, dtype: int64

# %%
df1_no_missing = new_df1.dropna()
df1_no_missing.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3   Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
#
# [5 rows x 10 columns]

# %%
new_df1.drop(['CELL_ON_SITE' , 'COUNTRY_A' , 'COUNTRY_B'], axis=1)
# Out:
#          PRODUCT  VALUE  ...     CELL_ID     SITE_ID
# 0          Voice      0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1            sms      0  ...  /+cKZKIp41  /+cKZKIp41
# 2            sms     25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3          Voice     56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4          Voice     14  ...  051KhYDCpv  051KhYDCpv
# 5           data      0  ...  /lrUXVGVcN  /lrUXVGVcN
# 6          Voice      0  ...  +38u2u/rfx  +38u2u/rfx
# 7          Voice      0  ...  09UjmmY1Ds  09UjmmY1Ds
# 8          Voice      0  ...  0DeimCpZOc  0DeimCpZOc
# 9            sms      0  ...  01MDiY5F89  01MDiY5F89
# 10           sms      0  ...  0Fmr/IZtQ+  0Fmr/IZtQ+
# 11           sms      0  ...  0MZBLLzPYZ  0MZBLLzPYZ
# 12           sms      0  ...  0//cZOoEXj  0//cZOoEXj
# 13           sms     25  ...  2dmu2Iy1CX  2dmu2Iy1CX
# 14         Voice      0  ...  0Fmr/IZtQ+  0Fmr/IZtQ+
# 15         Voice      0  ...  176sGHv7Ym  176sGHv7Ym
# 16         Voice     44  ...  ++ctND+jGD  ++ctND+jGD
# ...

# %%
new_df1.size
new_df1.shape
new_df1.ndim
# Out:
# 2

# %%
new_df1.size
# Out:
# 150118160

# %%
new_df1.describe()
# Out:
#               VALUE
# count  1.501182e+07
# mean   4.255369e+01
# std    9.046932e+01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    1.400000e+01
# 75%    5.400000e+01
# max    2.496000e+04

# %%
new_df1
